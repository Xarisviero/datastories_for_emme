# %% [markdown]
# <a href="https://colab.research.google.com/github/Xarisviero/datastories_for_emme/blob/main/Copy_of_Homework_week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Στη διεύθυνση https://raw.githubusercontent.com/thechaudharysab/imdb-data-pandas-visualization/master/data/imdb_1000.csv υπάρχει ένα αρχείο .csv, το οποίο περιέχει δεδομένα για ταινίες στο IMDB.

# %% [markdown]
# **Mε την python και τη βιβλιοθήκη pandas για την ανάλυση και τη matplotlib για την οπτικοποίηση, αναλύστε και οπτικοποιήστε τα δεδομένα**.

# %% [markdown]
# 1. Εισαγωγή βιβλιοθηκών

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# 2. Δημιουργία dataframe από το csv

# %%
# μέσα στην παρένθεση του read_csv() των pandas, βάζουμε σαν string, δηλαδή μέσα σε εισαγωγικά, το link του csv
movies_df = pd.read_csv("https://raw.githubusercontent.com/thechaudharysab/imdb-data-pandas-visualization/master/data/imdb_1000.csv")

# %% [markdown]
# 3. Επισκοπούμε τα δεδομένα μας (βλέπουμε τι περιλαμβάνουν)

# %%
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %% [markdown]
# 3.1. Βλέπουμε τις 5 πρώτες γραμμές των δεδομένων μας (με το head())

# %%
movies_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# 3.2. Βλέπουμε τις 5 τελευταίες γραμμές των δεδομένων (με το tail())

# %%
movies_df.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...

# %% [markdown]
# 3.3. Βλέπουμε πόσες γραμμές και πόσες στήλες έχει το dataframe (με το shape)

# %%
movies_df.shape
# Out:
# (979, 6)

# %% [markdown]
# 3.4. Βλέπουμε τα ονόματα των στηλών του dataframe (με το columns)

# %%
movies_df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %% [markdown]
# 3.5. Βλέπουμε τον τύπο δεδομένων της κάθε στήλης (με το dtypes)

# %%
movies_df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# 3.6. Βλέπουμε τα βασικά στατιστικά μεγέθη όλων των στηλών που περιλαμβάνουν αριθμητικά δεδομένα (με το describe())

# %%
movies_df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %% [markdown]
# 3.7. Συμπεράσματα από την πρώτη επισκόπηση του dataframe.
#
# Έχουμε ένα dataframe που περιλαμβάνει δεδομένα για 979 ταινίες από το IMDB.
#
# Στα δεδομένα περιλαμβάνονται:
# - ο τίτλος της κάθε ταινίας (στήλη 'title')
# - η βαθμολογία της (στήλη 'star_rating')
# - o χαρακτηρισμός του περιεχομένου της (στήλη 'content_rating')
# - το είδος της ταινίας (στήλη 'genre')
# - η διάρκειά της (στήλη 'duration')
# - οι βασικοί πρωταγωνιστές της (στήλη 'actors_list')
#
# Οι στήλες 'star_rating' και 'duration' περιέχουν αριθμητικά δεδομένα.
#
# Οι στήλες 'title' και 'actors_list' είναι λογικό να περιέχουν μοναδικές τιμές για κάθε ταινία (κάθε ταινία συνήθως έχει έναν μοναδικό τίτλο και μια μοναδική λίστα βασικών πρωταγωνιστών).
#
# Όμως, οι στήλες 'content_rating' και 'genre' περιέχουν συγκεκριμένες τιμές (πολλές ταινίες ανήκουν στο ίδιο είδος και έχουν την ίδια σήμανση).

# %% [markdown]
# 3.8. Περιγραφή συγκεκριμένων στηλών με ΜΗ αριθμητικά δεδομένα

# %% [markdown]
# 3.8.1. Περιγραφή της στήλης 'content_rating' (με το describe() στη συγκεκριμένη στήλη)

# %%
movies_df['content_rating'].describe()
# Out:
# count     976
# unique     12
# top         R
# freq      460
# Name: content_rating, dtype: object

# %% [markdown]
# To παραπάνω μας λέει ότι υπάρχουν 976 εγγραφές στη στήλη 'content_rating', με 12 μοναδικές τιμές, εκ των οποίων η συχνότερα εμφανιζόμενη είναι η 'R' με 460 εμφανίσεις. [Αν θέλετε να δείτε τι σημαίνει κάθε κωδικός, δείτε [ΕΔΩ](https://en.wikipedia.org/wiki/Motion_Picture_Association_film_rating_system)]
#
# Δεν μας λέει όμως ποιες είναι οι υπόλοιπες τιμές.

# %% [markdown]
# 3.8.2. Μοναδικές τιμές στη στήλη 'content_rating' (με το unique())

# %%
movies_df['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %% [markdown]
# Με το unique βλέπουμε όλες της μοναδικές τιμές της στήλης 'content_rating'.
#
# Αλλά δεν μας λέει και πόσες φορές εμφανίζεται η καθεμία.

# %% [markdown]
# 3.8.3. Μοναδικές τιμές της στήλης 'content_rating' και συχνότητα εμφάνισης της καθεμιάς (με το value_counts()).

# %%
movies_df['content_rating'].value_counts()
# Out:
# content_rating
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: count, dtype: int64

# %% [markdown]
# 3.8.4. Μοναδικές τιμές και συχνότητα εμφάνισης της καθεμίας σε γράφημα (με το plot()).
#
# Για τις παραμέτρους που δέχεται η plot(), δείτε [ΕΔΩ](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html)

# %%
# αν το παρακάτω κελί δεν εμφανίζει γράφημα, κάνετε uncomment και τρέξτε την παρακάτω εντολή
 #%matplotlib inline

# %%
# με την παράμετρο kind ορίζω το είδος του γραφήματος και με το title βάζω τίτλο στο γράφημα
# με το xlabel και το ylabel ορίζω τα labels στους άξονες x και y
# το kind είναι απαραίτητο να οριστεί αν θέλουμε γράφημα που δεν θα είναι line
# τα υπόλοιπα είναι προαιρετικά, αλλά ομορφαίνουν το γράφημα και το κάνουν κατανοητό
movies_df['content_rating'].value_counts().plot(kind="bar",
                                                title="Πλήθος ταινιών ανά είδος σήμανσης περιεχομένου",
                                                ylabel="Πλήθος ταινιών",
                                                xlabel="Σήμανση περιεχομένου")
# Out:
# <Axes: title={'center': 'Πλήθος ταινιών ανά είδος σήμανσης περιεχομένου'}, xlabel='Σήμανση περιεχομένου', ylabel='Πλήθος ταινιών'>

# %% [markdown]
# 3.8.5. Περιγραφή της στήλης 'genre' (με το describe() στη συγκεκριμένη στήλη).

# %%
movies_df['genre'].describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %% [markdown]
# 3.8.6. Μοναδικές τιμές στη στήλη 'genre' (με το unique())

# %%
 movies_df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %% [markdown]
# 3.8.7. Μοναδικές τιμές της στήλης 'genre' και συχνότητα εμφάνισης της καθεμιάς (με το value_counts()).

# %%
movies_df['genre'].value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %% [markdown]
# 3.8.8. Μοναδικές τιμές και συχνότητα εμφάνισης της καθεμίας σε γράφημα (με το plot()).

# %%
movies_df['genre'].value_counts().plot()
# Out:
# <Axes: xlabel='genre'>

# %% [markdown]
# 4. Διατύπωση ερωτημάτων

# %% [markdown]
# Αφού έχουμε επισκοπήσει τα δεδομένα μας, και έχουμε κατανοήσει τι περιλαμβάνουν, μπορούμε να αρχίσουμε να θέτουμε ερωτήματα και να παίρνουμε απαντήσεις.

# %% [markdown]
# 4.1. Ποιες είναι οι 10 ταινίες με τη μεγαλύτερη διάρκεια;

# %%
# ταξινομώ το dataframe ως προς τη στήλη 'duration' και ζητάω να μου δείξει τις πρώτες 10 γραμμές του dataframe
movies_df.sort_values(by="duration", ascending=False).head(10)
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 85           8.4                 Lawrence of Arabia             PG  Adventure
# 204          8.1                            Ben-Hur              G  Adventure
# 17           8.7                      Seven Samurai        UNRATED      Drama
# 767          7.6    It's a Mad, Mad, Mad, Mad World       APPROVED     Action
# 630          7.7                          Malcolm X          PG-13  Biography
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 85        216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 204       212  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...
# 630       202  [u'Denzel Washington', u'Angela Bassett', u'De...

# %% [markdown]
# Μπορώ να ζητήσω μόνο μια στήλη από το dataframe βάζοντας το όνομά της σε αγκύλες.

# %%
movies_df['title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %% [markdown]
# Aν θέλω να δω μόνο μια στήλη, αλλά σε μορφή dataframe, βάζω το όνομα της στήλης σε ΔΙΠΛΕΣ αγκύλες.

# %%
movies_df[['title']]
# Out:
#                                                title
# 0                           The Shawshank Redemption
# 1                                      The Godfather
# 2                             The Godfather: Part II
# 3                                    The Dark Knight
# 4                                       Pulp Fiction
# ..                                               ...
# 974                                          Tootsie
# 975                      Back to the Future Part III
# 976  Master and Commander: The Far Side of the World
# 977                                      Poltergeist
# 978                                      Wall Street
#
# [979 rows x 1 columns]

# %% [markdown]
# Μπορώ να βλέπω περισσότερες από μια επιλεγμένες στήλες του dataframe, βάζοντας τα ονόματα των στηλών που θέλω μέσα σε διπλές αγκύλες.

# %%
movies_df[['title', 'duration']].head()
# Out:
#                       title  duration
# 0  The Shawshank Redemption       142
# 1             The Godfather       175
# 2    The Godfather: Part II       200
# 3           The Dark Knight       152
# 4              Pulp Fiction       154

# %% [markdown]
# Μπορώ να ζητήσω πρώτα τις 5 πρώτες γραμμές του dataframe και μετά τις επιλεγμένες στήλες. Το αποτέλεσμα είναι το ίδιο με παραπάνω.

# %%
movies_df.head()[['title', 'duration']]
# Out:
#                       title  duration
# 0  The Shawshank Redemption       142
# 1             The Godfather       175
# 2    The Godfather: Part II       200
# 3           The Dark Knight       152
# 4              Pulp Fiction       154

# %% [markdown]
# Επομένως, μπορώ να ταξινομήσω το dataframe ως προς τη στήλη 'duration' σε φθήνουσα σειρά, να πάρω τις 10 πρώτες γραμμές και να δω μόνο τις στήλες 'title' και 'duration'.

# %%
movies_df.sort_values(by="duration", ascending=False).head(10)[['title', 'duration']]
# Out:
#                                  title  duration
# 476                             Hamlet       242
# 157                 Gone with the Wind       238
# 78         Once Upon a Time in America       229
# 142  Lagaan: Once Upon a Time in India       224
# 445               The Ten Commandments       220
# 85                  Lawrence of Arabia       216
# 204                            Ben-Hur       212
# 17                       Seven Samurai       207
# 767    It's a Mad, Mad, Mad, Mad World       205
# 630                          Malcolm X       202

# %% [markdown]
# 4.2. Ποιες είναι οι 5 ταινίες με τη μικρότερη διάρκεια;

# %%
movies_df.sort_values(by="duration", ascending=False).tail()[['title', 'duration']]
# Out:
#                            title  duration
# 293                    Duck Soup        68
# 88                       The Kid        68
# 258  The Cabinet of Dr. Caligari        67
# 338          Battleship Potemkin        66
# 389                       Freaks        64

# %% [markdown]
# 4.3. Ποιες είναι οι 10 ταινίες με τη μεγαλύτερη βαθμολογία (star_rating);

# %%
movies_df.sort_values(by="star_rating",ascending=False).head()[['title','star_rating']]
# Out:
#                       title  star_rating
# 0  The Shawshank Redemption          9.3
# 1             The Godfather          9.2
# 2    The Godfather: Part II          9.1
# 3           The Dark Knight          9.0
# 4              Pulp Fiction          8.9

# %% [markdown]
# 4.4. Ποιές είναι οι 10 ταινίες με τη μικρότερη βαθμολογία;

# %%
movies_df.sort_values(by="star_rating",ascending=False).tail()[['title','star_rating']]
# Out:
#              title  star_rating
# 948     Frances Ha          7.4
# 949     Home Alone          7.4
# 950          Bound          7.4
# 951  Sleepy Hollow          7.4
# 978    Wall Street          7.4

# %% [markdown]
# 4.5. Ποιες είναι οι 5 ταινίες δράσης με τη μεγαλύτερη βαθμολογία;

# %%
# επιλέγω από το dataframe τη στήλη 'genre'
movies_df['genre']
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: object

# %%
# θέλω το 'genre' να είναι 'action': δημιουργώ δηλαδή ένα φίλτρο, βάση του οποίου κάποιες γραμμές θα είναι Τrue και κάποιες False
movies_df['genre'] == 'Action'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
# θέλω το dataframe να εμφανίζει μόνο τις γραμμές που είναι True στην παραπάνω συνθήκη (δηλαδή να φιλτραριστεί το dataframe)
# γράφω το ονομα του dataframe και μέσα σε αγκύλες βάζω το φίλτρο
movies_df[movies_df['genre'] == 'Action']
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# 19              PG  Action       121
# 20               R  Action       136
# ..             ...     ...       ...
# 918              R  Action       122
# 954          PG-13  Action       104
# 963              R  Action       118
# 967              R  Action       136
# 976          PG-13  Action       138
#
#                                            actors_list
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 11   [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 19   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 20   [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# ..                                                 ...
# 918  [u'Paul Walker', u'Cameron Bright', u'Chazz Pa...
# 954  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# 963  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 967   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
#
# [136 rows x 6 columns]

# %% [markdown]
# Από την ένδειξη στο τέλος '136 rows x 6 columns', βλέπω ότι υπάρχουν 136 ταινίες δράσης (έχουν τιμή 'Action' στη στήλη 'genre').
#
# Τώρα μπορώ να τις ταξινομήσω ως προς το star_rating σε φθήνουσα σειρά και να πάρω τις 5 πρώτες.

# %%
movies_df[movies_df['genre'] == 'Action'].sort_values(by="star_rating", ascending=False).head()[["genre", "title", "star_rating"]]
# Out:
#      genre                                           title  star_rating
# 3   Action                                 The Dark Knight          9.0
# 12  Action  Star Wars: Episode V - The Empire Strikes Back          8.8
# 11  Action                                       Inception          8.8
# 19  Action                                       Star Wars          8.7
# 20  Action                                      The Matrix          8.7

# %% [markdown]
# **Σημείωση**: στο τέλος της παραπάνω εντολής, μέσα σε διπλές αγκύλες, δεν ζητάω απλώς τις τρεις στήλες που θέλω, αλλά τις βάζω και με τη σειρά που θέλω να εμφανίζονται.

# %% [markdown]
# 4.6. Ποιες είναι οι 5 δραματικές ταινίες με τη μεγαλύτερη βαθμολογία;

# %%
movies_df['genre']
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: object

# %%
movies_df['genre']=='Drama'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
movies_df[movies_df['genre'] == 'Drama']
# Out:
#      star_rating                            title content_rating  genre  \
# 5            8.9                     12 Angry Men      NOT RATED  Drama
# 9            8.9                       Fight Club              R  Drama
# 13           8.8                     Forrest Gump          PG-13  Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R  Drama
# 17           8.7                    Seven Samurai        UNRATED  Drama
# ..           ...                              ...            ...    ...
# 958          7.4               My Sister's Keeper          PG-13  Drama
# 968          7.4              The English Patient              R  Drama
# 970          7.4                      Wonder Boys              R  Drama
# 972          7.4                   Blue Valentine          NC-17  Drama
# 973          7.4            The Cider House Rules          PG-13  Drama
#
#      duration                                        actors_list
# 5          96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 9         139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 13        142    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# 16        133  [u'Jack Nicholson', u'Louise Fletcher', u'Mich...
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# ..        ...                                                ...
# 958       109  [u'Cameron Diaz', u'Abigail Breslin', u'Alec B...
# 968       162  [u'Ralph Fiennes', u'Juliette Binoche', u'Will...
# 970       107  [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# 972       112  [u'Ryan Gosling', u'Michelle Williams', u'John...
# 973       126  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
#
# [278 rows x 6 columns]

# %%
movies_df[movies_df['genre'] == 'Drama'].sort_values(by="star_rating", ascending=False).head()[["genre", "title", "star_rating"]]
# Out:
#     genre                            title  star_rating
# 5   Drama                     12 Angry Men          8.9
# 9   Drama                       Fight Club          8.9
# 13  Drama                     Forrest Gump          8.8
# 16  Drama  One Flew Over the Cuckoo's Nest          8.7
# 17  Drama                    Seven Samurai          8.7

# %% [markdown]
# Γράψτε 4 ακόμα δικές σας ερωτήσεις στα δεδομένα του dataframe και απαντήστε τες χρησιμοποιώντας όσα έχουμε μάθει παραπάνω.

# %% [markdown]
# 4.7 Ποια ιστορική ταινία έχει την χαμηλότερη **βαθμολογία**;

# %%
movies_df['genre']
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: object

# %%
movies_df['genre']=='History'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
movies_df[movies_df['genre']=='History']
# Out:
#      star_rating                title content_rating    genre  duration  \
# 338          8.0  Battleship Potemkin        UNRATED  History        66
#
#                                            actors_list
# 338  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...

# %%
movies_df[movies_df['genre'] == 'History'].sort_values(by="star_rating", ascending=False).tail()[["genre", "title", "star_rating"]]
# Out:
#        genre                title  star_rating
# 338  History  Battleship Potemkin          8.0

# %% [markdown]
# 4.8 Θέλω να μου βρεις τους ηθοποιούς στις 5 animated ταινές με την χαμηλότερη βαθμολογία

# %%
movies_df['genre']
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: object

# %%
movies_df['genre']=='Animation'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
movies_df[movies_df['genre']=='Animation']
# Out:
#      star_rating                   title content_rating      genre  duration  \
# 30           8.6           Spirited Away             PG  Animation       125
# 55           8.5           The Lion King              G  Animation        89
# 61           8.5  Grave of the Fireflies        UNRATED  Animation        89
# 64           8.4                  WALL-E              G  Animation        98
# 69           8.4       Princess Mononoke          PG-13  Animation       134
# ..           ...                     ...            ...        ...       ...
# 844          7.5               Pinocchio       APPROVED  Animation        88
# 853          7.5         L'illusionniste             PG  Animation        80
# 882          7.5                   Mulan              G  Animation        88
# 938          7.4     Alice in Wonderland              G  Animation        75
# 966          7.4      The Simpsons Movie          PG-13  Animation        87
#
#                                            actors_list
# 30   [u'Daveigh Chase', u'Suzanne Pleshette', u'Miy...
# 55   [u'Matthew Broderick', u'Jeremy Irons', u'Jame...
# 61   [u'Tsutomu Tatsumi', u'Ayano Shiraishi', u'Ake...
# 64    [u'Ben Burtt', u'Elissa Knight', u'Jeff Garlin']
# 69   [u'Y\xf4ji Matsuda', u'Yuriko Ishida', u'Y\xfb...
# ..                                                 ...
# 844  [u'Dickie Jones', u'Christian Rub', u'Mel Blanc']
# 853  [u'Jean-Claude Donda', u'Eilidh Rankin', u'Dun...
# 882      [u'Ming-Na Wen', u'Eddie Murphy', u'BD Wong']
# 938  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 966  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
#
# [62 rows x 6 columns]

# %%
movies_df[movies_df['genre'] == 'Animation'].sort_values(by="star_rating", ascending=False).tail()[["genre", "title", "star_rating","actors_list"]]
# Out:
#          genre                title  star_rating  \
# 844  Animation            Pinocchio          7.5
# 853  Animation      L'illusionniste          7.5
# 882  Animation                Mulan          7.5
# 938  Animation  Alice in Wonderland          7.4
# 966  Animation   The Simpsons Movie          7.4
#
#                                            actors_list
# 844  [u'Dickie Jones', u'Christian Rub', u'Mel Blanc']
# 853  [u'Jean-Claude Donda', u'Eilidh Rankin', u'Dun...
# 882      [u'Ming-Na Wen', u'Eddie Murphy', u'BD Wong']
# 938  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Ha...
# 966  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...

# %% [markdown]
# 4.9 Θέλω να μου βρεις ποιες κωμικές ταινίες movies έχουν την μικρότερη διάρκεια και να την παρουσιάσεις σε γράφημα;

# %%
movies_df['genre']
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: object

# %%
movies_df['genre'] == 'Comedy'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974     True
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
movies_df[movies_df['genre'] == 'Comedy']
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# ..           ...                                                ...
# 959          7.4                               Deconstructing Harry
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
#
#     content_rating   genre  duration  \
# 25           PG-13  Comedy       116
# 29          PASSED  Comedy        87
# 35               G  Comedy        87
# 48              PG  Comedy        95
# 52        APPROVED  Comedy       125
# ..             ...     ...       ...
# 959              R  Comedy        96
# 960          PG-13  Comedy       103
# 962             PG  Comedy        99
# 971              R  Comedy        90
# 974             PG  Comedy       116
#
#                                            actors_list
# 25   [u'Roberto Benigni', u'Nicoletta Braschi', u'G...
# 29   [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# 35   [u'Charles Chaplin', u'Paulette Goddard', u'He...
# 48   [u'Peter Sellers', u'George C. Scott', u'Sterl...
# 52   [u'Charles Chaplin', u'Paulette Goddard', u'Ja...
# ..                                                 ...
# 959  [u'Woody Allen', u'Judy Davis', u'Julia Louis-...
# 960  [u'Steve Carell', u'Toni Collette', u'Allison ...
# 962  [u'Morgan Freeman', u'Jessica Tandy', u'Dan Ay...
# 971  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
#
# [156 rows x 6 columns]

# %%
movies_df[movies_df['genre'] == 'Comedy'].sort_values(by="duration", ascending=False).tail()[["genre", "title", "duration"]]
# Out:
#       genre             title  duration
# 738  Comedy  Army of Darkness        81
# 622  Comedy   The Dinner Game        80
# 535  Comedy             Zelig        79
# 88   Comedy           The Kid        68
# 293  Comedy         Duck Soup        68

# %% [markdown]
# 4.10 Θέλω σε ένα γράφημα να μου βάλεις τις 5 καλύτερες mystery movies

# %%
movies_df['genre']
movies_df['genre'] == 'Mystery'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
movies_df[movies_df['genre'] == 'Mystery']
# Out:
#      star_rating                     title content_rating    genre  duration  \
# 38           8.6               Rear Window       APPROVED  Mystery       112
# 46           8.5                   Memento              R  Mystery       113
# 76           8.4                   Vertigo       APPROVED  Mystery       128
# 110          8.3     2001: A Space Odyssey              G  Mystery       160
# 149          8.2                   Rebecca      NOT RATED  Mystery       130
# 244          8.1            Shutter Island              R  Mystery       138
# 249          8.1                    Sleuth             PG  Mystery       138
# 264          8.1            Twelve Monkeys              R  Mystery       129
# 292          8.1  The Manchurian Candidate       APPROVED  Mystery       126
# 467          7.9              The 39 Steps        UNRATED  Mystery        86
# 583          7.8                 Dark City              R  Mystery       100
# 742          7.6                 Following              R  Mystery        69
# 863          7.5  Three Days of the Condor              R  Mystery       117
# 866          7.5          To Catch a Thief       APPROVED  Mystery       106
# 894          7.5               Source Code          PG-13  Mystery        93
# 965          7.4                 Limitless          PG-13  Mystery       105
#
#                                            actors_list
# 38   [u'James Stewart', u'Grace Kelly', u'Wendell C...
# 46   [u'Guy Pearce', u'Carrie-Anne Moss', u'Joe Pan...
# 76   [u'James Stewart', u'Kim Novak', u'Barbara Bel...
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...
# 149  [u'Laurence Olivier', u'Joan Fontaine', u'Geor...
# 244  [u'Leonardo DiCaprio', u'Emily Mortimer', u'Ma...
# 249  [u'Laurence Olivier', u'Michael Caine', u'Alec...
# 264  [u'Bruce Willis', u'Madeleine Stowe', u'Brad P...
# 292  [u'Frank Sinatra', u'Laurence Harvey', u'Janet...
# 467  [u'Robert Donat', u'Madeleine Carroll', u'Luci...
# 583  [u'Rufus Sewell', u'Kiefer Sutherland', u'Jenn...
# 742  [u'Jeremy Theobald', u'Alex Haw', u'Lucy Russe...
# 863  [u'Robert Redford', u'Faye Dunaway', u'Cliff R...
# 866  [u'Cary Grant', u'Grace Kelly', u'Jessie Royce...
# 894  [u'Jake Gyllenhaal', u'Michelle Monaghan', u'V...
# 965  [u'Bradley Cooper', u'Anna Friel', u'Abbie Cor...

# %%
movies_df[movies_df['genre'] == 'Mystery'].sort_values(by="star_rating", ascending=False).head()[["star_rating","genre", "title",]].plot(kind="bar",
                                                                                                                                    x="title",
                                                                                                                                    y="star_rating")
# Out:
# <Axes: xlabel='title'>
